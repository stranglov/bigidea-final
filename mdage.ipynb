# %%
import pandas as pd
import numpy as np

# %%
import ssl
ssl._create_default_https_context=ssl._create_unverified_context

# %%
pgh_death_data = pd.read_csv("https://data.wprdc.org/dataset/ee735209-4de7-4ea4-b446-bf0f0f6d9cb3/resource/c2e1500a-a12a-4e91-be94-76c6a892b7e2/download/nhoodmedianage20112015.csv")

pgh_death_data.head()
# Out:
#      NEIGHBORHOOD  BLACKdeaths  Black MD AGE AT DEATH  WHITEdeaths  \
# 0     SOUTH SHORE          0.0                    0.0          0.0
# 1         CHATEAU          0.0                    0.0          2.0
# 2     NORTH SHORE          0.0                    0.0          4.0
# 3  ALLEGHENY WEST          3.0                    NaN          4.0
# 4     SAINT CLAIR          5.0                   67.5          5.0
#
#    White MD AGE AT DEATH  TOTALdeaths*  TOTAL MD AGE AT DEATH
# 0                    0.0           0.0                    0.0
# 1                    NaN           2.0                    NaN
# 2                    NaN           5.0                   80.0
# 3                    NaN           8.0                   65.0
# 4                   67.5          10.0                   67.5

# %%
pgh_death_data.sort_values("TOTAL MD AGE AT DEATH")
# Out:
#                                NEIGHBORHOOD  BLACKdeaths  \
# 0                               SOUTH SHORE          0.0
# 9                                 FAIRYWOOD         11.0
# 7                         ARLINGTON HEIGHTS         10.0
# 3                            ALLEGHENY WEST          3.0
# 49                           EAST ALLEGHENY         51.0
# 42                                ALLENTOWN         41.0
# 38                               MANCHESTER         97.0
# 4                               SAINT CLAIR          5.0
# 22                        NORTHVIEW HEIGHTS         51.0
# 14                     CALIFORNIA-KIRKBRIDE         16.0
# 17                                    BLUFF         18.0
# 70                       MARSHALL-SHADELAND         55.0
# 48                  TROY HILL/HERR'S ISLAND         15.0
# 23                                 FINEVIEW         19.0
# 54                               EAST HILLS        171.0
# ...
