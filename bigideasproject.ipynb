# %%
import pandas as pd
import numpy as np
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

data = pd.read_csv("https://data.wprdc.org/dataset/b049da40-910a-4b9d-9438-ff584e432bb1/resource/fce248f0-8697-4d2a-bbe0-2da826776bfa/download/obesity-ac-2006-2010censustracts.csv")
data.head(417)
data.sort_values("2006-2010 estimate of obesity")
# Out:
#            stname    tractfips  2000 Tract               2010 Tract  \
# 369  Pennsylvania  42003562000       40300          562000 & 982200
# 48   Pennsylvania  42003140100      140100                      NaN
# 6    Pennsylvania  42003040500       40500                      NaN
# 18   Pennsylvania  42003070600       70600                      NaN
# 413  Pennsylvania  42003981200      220500          563200 & 981200
# 20   Pennsylvania  42003070900       70900                      NaN
# 391  Pennsylvania  42003563800      433000                   563800
# 16   Pennsylvania  42003070300       70300                      NaN
# 17   Pennsylvania  42003070500       70500                      NaN
# 19   Pennsylvania  42003070800       70800                      NaN
# 49   Pennsylvania  42003140200      140200                      NaN
# 415  Pennsylvania  42003982200       50700          562000 & 982200
# 145  Pennsylvania  42003422000      422000                      NaN
# ...

# %%
# Out:
#      Census_tract  ED_visits  ED_hosp  UC_visits  Asthma_use  Total_members
# 388   42003980000          0        0          0           0              1
# 394   42003980700          0        0          0           1              2
# 392   42003980500          0        0          0           2              4
# 390   42003980300          0        0          0           0              4
# 389   42003980100          0        0          0           1              4
# 393   42003980600          0        0          0           0              5
# 391   42003980400          0        0          0           1              6
# 395   42003981000          0        0          0           0              8
# 396   42003981800          0        0          0           0             13
# 7     42003040600          0        0          0           0             15
# 5     42003040400          0        0          0           1             17
# ...
